# %%
import matplotlib.pyplot as plt

eje_x_years = [1975, 1980, 1985, 1990, 1995, 2000, 2005, 2010, 2015]
eje_y_prices = [1243, 1543, 1619, 1831, 1960, 2310, 2415, 2270, 1918]

plt.plot(eje_x_years, eje_y_prices, label = 'LABEL')
plt.title('Titulo')
plt.xlabel('Years')
plt.ylabel('Precio')

plt.show()

# %%
# [...]
plt.savefig('Precios.png')
plt.show()

# %% [markdown]
# Consejos para portátiles
# Puede usar ipywidgets para gráficos interactivos
#
# !pip install ipywidgets
#
# %matplotlib widget # enable interactivity in your notebook
# %matplotlib inline # get back to normal mode
#
# Advertencia: con los widgets, es posible que encuentre problemas de compatibilidad. Le recomendamos que lo use solo cuando sea necesario.
#
# No necesitas escribir plt.show() en el contexto de un cuaderno.
# Asegúrate de usar ; en la línea final para evitar imprimir su salida

# %%
# !pip install ipywidgets
# %matplotlib widget # enable interactivity in your notebook
# %matplotlib inline # get back to normal mode
# Out:
# ...
# WARNING: You are using pip version 21.3.1; however, version 22.2.2 is available.
# You should consider upgrading via the 'C:\Users\alejo\poo_teorica\Scripts\python.exe -m pip install --upgrade pip' command.
# UsageError: unrecognized arguments: # enable interactivity in your notebook

# %%
plt.plot(eje_x_years, eje_y_prices)

# %%
plt.plot(eje_x_years, eje_y_prices);

# %% [markdown]
# Title
# 👉 matplotlib.pyplot.title
#
# ```python
# plt.title("Precios por años")
# ```
# Axis labels
# 👉 matplotlib.pyplot.xlabel and matplotlib.pyplot.ylabel
#
# ```python
# plt.xlabel("Años")
# plt.ylabel("Precios en dolares")
# ```
# Axis ticks
# 👉 matplotlib.pyplot.xticks & matplotlib.pyplot.yticks
#
# For example:
# ```python
# plt.xticks([1975, 1995, 2015], ['start', 1995, 'end'])
# plt.yticks([0, 5000])
# ```
# 💡2 Metodos útiles para matplot: matplotlib.pyplot.xlim & matplotlib.pyplot.ylim
#
# Agreguemos dos lineas ,as
# ```python
# petroleo_y = [823, 1136, 1367, 1547, 1660, 1927, 1983, 1827, 1352]
# gasoil_y = [171, 200, 166, 175, 228, 280, 319, 399, 529]
# ```

# %%
petroleo_y = [823, 1136, 1367, 1547, 1660, 1927, 1983, 1827, 1352]
gasoil_y = [171, 200, 166, 175, 228, 280, 319, 399, 529]

# %% [markdown]
# Plotemos petroleo y gasoil
#
# ```python
# plt.plot(eje_x_years, petroleo_y)
# plt.plot(eje_x_years, gasoil_y)
# ```
# Legend
# 👉 matplotlib.pyplot.legend
#
# Agregale un label a cada plot
# ```python
# plt.plot(eje_x_years, eje_y_prices, label="Precios Totales")
# plt.plot(eje_x_years, petroleo_y, label="Precios Petroleo")
# plt.plot(eje_x_years, gasoil_y, label="Precios Gasoil")
# ```
# Probá
# ```python
# plt.legend(loc="best")
# ```
# Grid
# 👉 matplotlib.pyplot.grid
#
# Example:
# ```python
# plt.grid(axis="y", linewidth=0.5)
# ```

# %%
plt.plot(eje_x_years, eje_y_prices, label="Precios Totales")
plt.plot(eje_x_years, petroleo_y, label="Precios Petroleo")
plt.plot(eje_x_years, gasoil_y, label="Precios Gasoil")

plt.legend(loc='best')

plt.grid(axis='y',linewidth=0.5)

# %% [markdown]
# # Styles

# %%
print(sorted(plt.style.available))
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']

# %%
with plt.style.context('Solarize_Light2'):
    # [...]
    plt.show()

# %%
with plt.style.context('Solarize_Light2'):
    plt.plot(eje_x_years, eje_y_prices)
    plt.show()

# %% [markdown]
# # Lineas
# Tenes control absolute de las lineas: matplotlib.lines.Line2D:
#
# color (cycled, see plt.rcParams['axes.prop_cycle'])
# marker (default: None)
# linestyle (default: "-")
# linewidth (default: 1.5)
# For example:

# %%
plt.plot(eje_x_years, eje_y_prices, color="#999999", linestyle=':', marker='s')
plt.plot(eje_x_years, petroleo_y, linewidth=3)

# %% [markdown]
# # Figure Size
# plt.figure(figsize=(10,5))

# %%
plt.figure(figsize= (10,5))

# 3 lines plot
plt.plot(eje_x_years, eje_y_prices, label="Precios Totales")
plt.plot(eje_x_years, petroleo_y, label="Precios Petroleo")
plt.plot(eje_x_years, gasoil_y, label="Precios Gasoil")
# Decoration
plt.legend()
plt.title('Precios de las materias primas desde 1975 hasta 2015')
plt.ylim((0,3000))
plt.ylabel('USD')
plt.grid(lw=0.5)

plt.show()

# %% [markdown]
# # Axis
#
# 👉 matplotlib.axes
#
# You can access the current Axes instance with matplotlib.pyplot.gca
#
# ax = plt.gca()

# %%
#mira este ejemplo
plt.plot(eje_x_years, eje_y_prices)
plt.ylabel('USD')
plt.title('Precios 1975 - 2015')
plt.show()

# %%
#comparalo a este
plt.plot(eje_x_years, eje_y_prices)
# Access the ax first
ax = plt.gca() 
# then change its properties  
ax.set_title('Precios 1975 - 2015')
ax.set_ylabel('USD')
ax.spines['bottom'].set_position(('data', 850)) # 850 on y-axis
plt.show()

# %% [markdown]
# #### Tunear el gráfico
#
# ```python
# ax.spines
# ```
#
# ```python
# OrderedDict([('left', <matplotlib.spines.Spine at 0x116e400d0>),
#              ('right', <matplotlib.spines.Spine at 0x116e401c0>),
#              ('bottom', <matplotlib.spines.Spine at 0x116e402b0>),
#              ('top', <matplotlib.spines.Spine at 0x116e403a0>)])
# ```
#
# Podes setear un color
# ```python
# ax.spines['right'].set_color(None)
# ```
# También la posición exacta Spine.set_position:
# ```python
# ax.spines['bottom'].set_position(('axes', 0.5)) # half of y-axis
# ```
#
# ```python
# ax.spines['bottom'].set_position(('data', 850)) # 850 on y-axis
# ```

# %% [markdown]
# # Figures, Subplots and Axes
#
# Una figura en matplotlib significa la ventana completa en la interfaz de usuario.
# Dentro de esta figura puede haber varias subtramas
# Las subtramas se organizan y numeran en una cuadrícula (nrow, ncol) como se muestra a continuación
#
# las subparcelas pertenecen a la clase Ejes: considérenlas equivalentes en primer orden.
#
# La única diferencia: puede crear un hacha sin una cuadrícula de trama secundaria, colocándola en una posición absoluta dentro de una figura https://stackoverflow.com/questions/43326680/what-are-the-differences-between-add-axes-and-add-subplot/43330553#43330553

# %%
# Start a figure
plt.figure(figsize=(10,3))
# First subplot
plt.subplot(1,2,1)
plt.plot(eje_x_years, eje_y_prices, label="Precios Totales")
plt.plot(eje_x_years, petroleo_y, label="Precios Petroleo")
plt.title('Total vs. Petroleo')
plt.legend()
# Second subplot
plt.subplot(1,2,2) 
plt.plot(eje_x_years, eje_y_prices, label="total", c='black')
plt.title("Todas las materias primas")
# Global figure methods
plt.suptitle('1975 - 2015')
plt.show()

# %%
plt.figure(figsize=(10,3))
plt.subplot(1,2,1)
plt.plot(eje_x_years, eje_y_prices, label="Precios Totales")
plt.plot(eje_x_years, petroleo_y, label="Precios Petroleo")
plt.title('Total vs. Petroleo')

plt.subplot(1,2,2)
plt.plot(eje_x_years, eje_y_prices, label="total", c='black')
plt.title("Todas las materias primas")
# Out:
# Text(0.5, 1.0, 'Total vs. Petroleo')

# %% [markdown]
# ### fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2)

# %%
# Destructuring initialization
fig, axs = plt.subplots(1, 2, figsize=(10,3)) # axs is a (1,2) nd-array

# First subplot
axs[0].plot(eje_x_years, eje_y_prices, label="Precios Totales")
axs[0].plot(eje_x_years, petroleo_y, label="Precios Petroleo")
axs[0].set_title('Total vs. Petroleo')
axs[0].legend()
# Second subplot
axs[1].plot(eje_x_years, eje_y_prices, c='black')
axs[1].set_title("Todas las materias primas")
# Global figure methods
plt.suptitle('1975 - 2015')
plt.show()

# %% [markdown]
# # Pandas

# %%
import pandas as pd
df = pd.DataFrame({ 'petroleo': petroleo_y, 'gasoil': gasoil_y }, index=eje_x_years)
df
# Out:
#       petroleo  gasoil
# 1975       823     171
# 1980      1136     200
# 1985      1367     166
# 1990      1547     175
# 1995      1660     228
# 2000      1927     280
# 2005      1983     319
# 2010      1827     399
# 2015      1352     529

# %%
df.plot();

# %%
import pandas as pd
ax = df.plot()
ax.set_title('Combustibles')
ax
# Out:
# <AxesSubplot:title={'center':'Combustibles'}>

# %% [markdown]
# Cuidado con los métodos de pandas!!!
#
# pandas.DataFrame.plot
#
# df.plot() # Todas las columnas contra el indice
# ax = df.plot() # Esto es un Axis
# matplotlib.pyplot.plot
#
# plt.plot(df) # en el método original no es un axis (matplotlib.lines.Line2D in our case)
# ax = plt.gca() # tenemos que presentarlo de esta manera para acceder como axis

# %%
# !ls
# Out:
# 'ls' is not recognized as an internal or external command,
# operable program or batch file.

# %% [markdown]
# # Bar Chart
# Un diagrama de barras o diagrama de barras es un gráfico que representa la categoría de datos con barras rectangulares con longitudes y alturas proporcionales a los valores que representan. Los gráficos de barras se pueden trazar horizontal o verticalmente. Un gráfico de barras describe las comparaciones entre las categorías discretas.
# Uno de los ejes del gráfico representa las categorías específicas que se comparan, mientras que el otro eje representa los valores medidos correspondientes a esas categorías.

# %%
Data= pd.read_csv("../data_extra/bar_chart_data.csv")

# %%
Data
# Out:
#            Brand  Cars Listings
# 0           Audi            419
# 1            BMW            636
# 2  Mercedes-Benz            820
# 3     Mitsubishi            306
# 4        Renault            438
# 5         Toyota            509
# 6     Volkswagen            875

# %%
plt.figure(figsize=(9,6))
plt.bar(x=Data["Brand"],height=Data["Cars Listings"],color="midnightblue")
plt.xticks(rotation=45)
plt.yticks(fontsize=12)
plt.title("Car listings by Brand",fontsize=16,fontweight='bold')
plt.ylabel("Car Listings", fontsize=14)
plt.show()

# %% [markdown]
# # Pie Chart
#
# Un gráfico circular es un diagrama estadístico circular que puede mostrar solo una serie de datos. El área del gráfico es el porcentaje total de los datos dados. El área de rebanadas del pastel representa el porcentaje de las partes de los datos.

# %%
pie_data=pd.read_csv("../data_extra/pie_chart_data.csv")
pie_data
# Out:
#   Engine Fuel Type  Number of Cars
# 0           Diesel            2019
# 1              Gas             613
# 2            Other             154
# 3           Petrol            1559

# %%
import seaborn as sns
sns.set_palette('colorblind')
plt.figure(figsize=(10,8))
plt.pie(pie_data["Number of Cars"],
   labels=pie_data["Engine Fuel Type"],
    autopct='%.2f%%',
    textprops={"size": "x-large",
              "rotation": "30"})
plt.legend()
plt.title("Cars by fuel type", fontsize="16",fontweight="bold")
plt.show()

# %% [markdown]
# # Stacked Bar Chart
# Los diagramas de barras apiladas representan diferentes grupos en la parte superior de 1 otro. El pico de la barra depende de la altura resultante de la mezcla de los resultados de los grupos. Va desde el fondo hasta el valor en lugar de ir desde cero hasta el valor.

# %%
stack_data=pd.read_csv("../data_extra/stacked_area_chart_data.csv")
stack_data.head()
# Out:
#    Year   Gas  Petrol  Diesel  Other
# 0  1982     0      94       0      0
# 1  1983     0     347       0      0
# 2  1984   300       0     334      0
# 3  1985  1030    1184     984      0
# 4  1986   511     681    1066    340

# %%
plt.figure(figsize=(12,6))
sns.set_style("white")
labels=["Gas","Petrol","Diesel"]
plt.stackplot(stack_data["Year"],
              stack_data["Gas"],
              stack_data["Petrol"],
              stack_data["Diesel"],
              edgecolor='none',
              colors=["#FFB6C1","FF00FF","#9400D3"])
plt.xticks(stack_data["Year"], rotation=90)
plt.title("Popularity of engine fuel types(1982-2016)", fontsize=14, weight="bold")
plt.legend(labels=labels, loc='upper left')
sns.despine()
plt.show()

# %% [markdown]
# # Line Charts
# Representan relación entre X e Y

# %%
line_chart=pd.read_csv("../data_extra/line_chart_data.csv")
line_chart
# Out:
#             Date   GSPC500   FTSE100
# 0       1/3/2000  0.003264  0.000000
# 1       1/4/2000 -0.009549  0.000000
# 2       1/5/2000 -0.038345 -0.038137
# 3       1/6/2000  0.001922 -0.019502
# 4       1/7/2000  0.000956 -0.013571
# ...          ...       ...       ...
# 2865  12/27/2010 -0.002282  0.002135
# 2866  12/28/2010  0.003539  0.000000
# 2867  12/29/2010 -0.000254  0.000000
# 2868  12/30/2010  0.000524 -0.002080
# 2869  12/31/2010 -0.002128 -0.004236
#
# [2870 rows x 3 columns]

# %%
line_chart.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2870 entries, 0 to 2869
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Date     2870 non-null   object
#  1   GSPC500  2870 non-null   float64
#  2   FTSE100  2870 non-null   float64
# dtypes: float64(2), object(1)
# memory usage: 67.4+ KB

# %%
line_chart["date"]=pd.to_datetime(line_chart["Date"])

# %%
line_chart["date"]
# Out:
# 0      2000-01-03
# 1      2000-01-04
# 2      2000-01-05
# 3      2000-01-06
# 4      2000-01-07
#           ...
# 2865   2010-12-27
# 2866   2010-12-28
# 2867   2010-12-29
# 2868   2010-12-30
# 2869   2010-12-31
# Name: date, Length: 2870, dtype: datetime64[ns]

# %%
plt.figure(figsize=(20,8))
plt.plot(line_chart["date"],line_chart["GSPC500"])
plt.plot(line_chart["date"],line_chart["FTSE100"])
plt.title("S&P vs FTSE return(2000-2010)",fontsize=14,weight="bold")
plt.legend(labels=["Date","S&P 500","FTSE 100"], loc="upper left")
plt.show()

# %% [markdown]
# Medio complejo de analizar. ¿Que podemos hacer?

# %%
df_2009= line_chart[(line_chart.date>="2009-07-01") & (line_chart.date<="2009-12-31")]
df_2009
# Out:
#             Date   GSPC500   FTSE100       date
# 2477    7/1/2009 -0.006827 -0.010433 2009-07-01
# 2478    7/2/2009  0.000456  0.021533 2009-07-02
# 2479    7/3/2009  0.000000 -0.024512 2009-07-03
# 2480    7/6/2009 -0.029276  0.000472 2009-07-06
# 2481    7/7/2009  0.004842 -0.009773 2009-07-07
# ...          ...       ...       ...        ...
# 2604  12/25/2009  0.000000  0.000000 2009-12-25
# 2605  12/28/2009  0.005753  0.000000 2009-12-28
# 2606  12/29/2009  0.000905  0.000000 2009-12-29
# 2607  12/30/2009 -0.002676  0.006516 2009-12-30
# 2608  12/31/2009  0.000951 -0.004542 2009-12-31
#
# [132 rows x 4 columns]

# %%
plt.figure(figsize=(20,8))
plt.plot(df_2009["date"],df_2009["GSPC500"],color="midnightblue")
plt.plot(df_2009["date"],df_2009["FTSE100"],color="crimson")
plt.title("S&P vs FTSE return(2000-2010)",fontsize=14,weight="bold")
plt.legend(labels=["Date","S&P 500","FTSE 100"], loc="upper left",fontsize="large")
plt.show()

# %% [markdown]
# # Histograma
#
# Un histograma se utiliza básicamente para representar los datos proporcionados en forma de algunos grupos. Es un método preciso para la representación gráfica de la distribución de datos numéricos. sobre la frecuencia.

# %%
hist_data=pd.read_csv("../data_extra/histogram_data.csv")
hist_data
# Out:
#        ID  Building Type  Year of sale  Month of sale Type of property  \
# 0    1030              1        2005.0           11.0        Apartment
# 1    1029              1        2005.0           10.0        Apartment
# 2    2002              2        2007.0            7.0        Apartment
# 3    2031              2        2007.0           12.0        Apartment
# 4    1049              1        2004.0           11.0        Apartment
# ..    ...            ...           ...            ...              ...
# 262  5044              5           NaN            NaN        Apartment
# 263  5047              5           NaN            NaN        Apartment
# 264  5048              5           NaN            NaN        Apartment
# 265  5050              5           NaN            NaN        Apartment
# 266  5051              5           NaN            NaN        Apartment
#
#      Property #  Area (ft.)  Price
# 0            30      743.09    246
# 1            29      756.21    246
# ...

# %%
plt.figure(figsize=(9,6))
sns.set_style("white")
plt.hist(hist_data["Price"], bins=8, color="#008080")
plt.title("Distribution of Real State Prices", fontsize=14, weight="bold")
plt.xlabel("Price")
sns.despine()
plt.show()

# %% [markdown]
# # Scatter Plots
#
# Los diagramas de dispersión se utilizan para observar la relación entre las variables y utilizan puntos para representar la relación entre ellas. Los diagramas de dispersión se usan ampliamente para representar la relación entre variables y cómo el cambio en uno afecta al otro.

# %%
scatter_data= pd.read_csv("../data_extra/scatter_data.csv")

# %%
scatter_data
# Out:
#        ID  Building Type  Year of sale  Month of sale Type of property  \
# 0    1030              1        2005.0           11.0        Apartment
# 1    1029              1        2005.0           10.0        Apartment
# 2    2002              2        2007.0            7.0        Apartment
# 3    2031              2        2007.0           12.0        Apartment
# 4    1049              1        2004.0           11.0        Apartment
# ..    ...            ...           ...            ...              ...
# 262  5044              5           NaN            NaN        Apartment
# 263  5047              5           NaN            NaN        Apartment
# 264  5048              5           NaN            NaN        Apartment
# 265  5050              5           NaN            NaN        Apartment
# 266  5051              5           NaN            NaN        Apartment
#
#      Property #  Area (ft.)      Price    Status
# 0            30      743.09  246.17268     Sold
# ...

# %%
plt.figure(figsize=(9,6))
scatter=plt.scatter(scatter_data["Area (ft.)"],
            scatter_data["Price"],
           alpha=0.6,
           c=scatter_data["Building Type"],
           cmap='viridis')
plt.title("Area V/S Price", fontsize=14, weight="bold")
plt.xlabel("Area")
plt.ylabel("Price")
plt.legend(*scatter.legend_elements(), loc="upper left", title="Building Type")
plt.show()

# %% [markdown]
# # Regression Plots
#
# Los gráficos de regresión, como sugiere el nombre, crean una línea de regresión entre 2 parámetros y ayudan a visualizar sus relaciones lineales.
# Podemos trazar gráficos de regresión usando dos métodos:
# sns.regplot()
# sns.lmplot()
# Veamos ambos en detalle.

# %%
regression_data=pd.read_csv("../data_extra/scatter_plot_ii.csv")
regression_data.head()
# Out:
#    Budget  Sales
# 0   337.1   22.1
# 1   128.9   10.4
# 2   132.4    9.3
# 3   251.3   18.5
# 4   250.0   12.9

# %%
plt.figure(figsize=(9,6))
sns.regplot(x="Budget",
            y="Sales",
            data= regression_data,
            scatter_kws={'color':'k'},
            line_kws={'color':'green'})
plt.title("Effect of Budget on Sales", fontsize=14, weight="bold")
plt.show()

# %%
regression_data_2= pd.read_csv("../data_extra/scatter_data.csv")
regression_data_2
# Out:
#        ID  Building Type  Year of sale  Month of sale Type of property  \
# 0    1030              1        2005.0           11.0        Apartment
# 1    1029              1        2005.0           10.0        Apartment
# 2    2002              2        2007.0            7.0        Apartment
# 3    2031              2        2007.0           12.0        Apartment
# 4    1049              1        2004.0           11.0        Apartment
# ..    ...            ...           ...            ...              ...
# 262  5044              5           NaN            NaN        Apartment
# 263  5047              5           NaN            NaN        Apartment
# 264  5048              5           NaN            NaN        Apartment
# 265  5050              5           NaN            NaN        Apartment
# 266  5051              5           NaN            NaN        Apartment
#
#      Property #  Area (ft.)      Price    Status
# 0            30      743.09  246.17268     Sold
# ...

# %%
sns.lmplot(x="Area (ft.)",
          y="Price",
          data=regression_data_2,
          scatter_kws={'color':'k'},
          line_kws={'color':'red'},
          height=6)
sns.set()
plt.title("Effect of Area on Price", fontsize=14, weight="bold")
plt.show()

# %% [markdown]
# # Bar and Line Chart

# %%
combined_data= pd.read_csv("../data_extra/bar_line_chart_data.csv")
combined_data.head()
# Out:
#    Year  Python Users  Participants
# 0  2012         0.149           798
# 1  2013         0.133          1880
# 2  2014         0.195          3285
# 3  2015         0.303          2800
# 4  2016         0.458          2895

# %%
from matplotlib.ticker import PercentFormatter
sns.set_style("white")
fig, ax= plt.subplots(figsize=(10,7))
ax.bar(combined_data["Year"],
      combined_data["Participants"],
      color='k')
ax.set_ylabel("Number of Participants", fontsize=14, weight="bold")
ax1= ax.twinx()
ax1.set_ylim(0,1)
ax1.yaxis.set_major_formatter(PercentFormatter(xmax=1.0))
ax1.plot(combined_data["Year"],
      combined_data["Python Users"],
      color='#b60000',
      marker='D')
ax1.set_ylabel("Python Users", fontsize=14, weight="bold")
ax.set_title("KD Nuggets Survey Python Users", fontsize=14, weight="bold")
plt.show()
